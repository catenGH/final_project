# %%
import requests
import json
import csv

# %%
def ingredient_input():
    ingredient_list = []
    def user_input():
        users_input = input("Do you want to add an ingredient to your list? y/n:").lower()
        if users_input == "y":
            ingredient = input("Add an ingredient: ").lower()
            ingredient_list.append(ingredient)
            user_input()
        elif users_input == "n":
            print("Okay :<")
        else:
            print("Please put y or n!")
            user_input()
    user_input()
    print(ingredient_list)

ingredient_input()
# Out:
# Okay :<
# ['peanut', 'apple', 'sugar', 'chicken']

# %%
# this is a function to input the user's main ingredient and get a list of dish names and pictures, can also tweak it to get recipes

def ingredient_input():
    csv_file = open("recipes.csv", "w", newline="", encoding="utf-8")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Recipe Name", "Thumbnail Link", "Ingredients", "Cook Time (in minutes)", "Diet", "Cuisine", "Recipe Source"])
    ingredient_list = []
    def user_input():
        while True:
            users_input = input("Do you want to add an ingredient to your list? y/n: ").lower()
            if users_input == "y":
                ingredient = input("Add an ingredient: ").lower()
                ingredient_list.append(ingredient)
            elif users_input == "n":
                break
            else:
                print("Please enter 'y' or 'n'!")
    user_input()
    key = "5cb09004fe27449689868405b5a33789"
    find_ingredients = requests.get(f"https://api.spoonacular.com/recipes/findByIngredients?ingredients={ingredient_list}&apiKey={key}")
    ingredients_json = find_ingredients.json()
    for recipe in ingredients_json:
        id_num = recipe["id"]
        recipe_info = requests.get(f"https://api.spoonacular.com/recipes/{id_num}/information?apiKey={key}").json()
        recipe_name = recipe_info["title"]
        recipe_pic = recipe_info["image"]
        cook_time = recipe_info["readyInMinutes"]
        recipe_diets = recipe_info["diets"]
        if recipe_info["cuisines"]:
            recipe_cuisine = recipe_info["cuisines"]
        else:
            recipe_cuisine = "NaN"
        ingredients_list = []
        for i in recipe_info["extendedIngredients"]:
            ingredient_name = i["nameClean"]
            ingredients_list.append(ingredient_name)
        recipe_source = recipe_info["sourceUrl"]
        csv_writer.writerow([recipe_name, recipe_pic, ingredients_list, cook_time, recipe_diets, recipe_cuisine, recipe_source])
    csv_file.close()

ingredient_input()

# %%
key = "&apiKey=6eccbe1676054b1e9304c8d1f5225764"
ingredient_list = ["apple", "chicken"]
find_ingredients = requests.get(f"https://api.spoonacular.com/recipes/findByIngredients?ingredients={ingredient_list}{key}")
ingredients_json = find_ingredients.json()
ingredients_json
# Out:
# [{'id': 673463,
#   'title': 'Slow Cooker Apple Pork Tenderloin',
#   'image': 'https://img.spoonacular.com/recipes/673463-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 2,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 6008,
#     'amount': 2.0,
#     'unit': 'cups',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Canned and Jarred',
#     'name': 'beef broth',
#     'original': '2 cups beef broth',
#     'originalName': 'beef broth',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/beef-broth.png'},
#    {'id': 10218,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': 'pork tenderloin',
#     'original': 'Pork Tenderloin',
#     'originalName': 'Pork Tenderloin',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/pork-tenderloin-raw.png'}],
#   'usedIngredients': [{'id': 9003,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Produce',
#     'name': 'apple r',
#     'original': 'apple slicer (*optional)',
#     'originalName': 'apple slicer (*optional)',
#     'meta': ['(*optional)'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'},
#    {'id': 1069003,
#     'amount': 2.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'apples',
#     'original': '2 green apples',
#     'originalName': 'green apples',
#     'meta': ['green'],
#     'extendedName': 'green apples',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/grannysmith-apple.png'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 0},
#  {'id': 44789,
#   'title': 'Bangers and Mash',
#   'image': 'https://img.spoonacular.com/recipes/44789-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 2,
#   'missedIngredientCount': 13,
#   'missedIngredients': [{'id': 11435,
#     'amount': 4.0,
#     'unit': 'medium',
#     'unitLong': 'mediums',
#     'unitShort': 'medium',
#     'aisle': 'Produce',
#     'name': 'rutabagas',
#     'original': '4 mediums Rutabagas, peeled and quartered',
#     'originalName': 's Rutabagas, peeled and quartered',
#     'meta': ['peeled', 'quartered'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/rutabaga.jpg'},
#    {'id': 11353,
#     'amount': 4.0,
#     'unit': 'large',
#     'unitLong': 'larges',
#     'unitShort': 'large',
#     'aisle': 'Produce',
#     'name': 'russet potatoes',
#     'original': '4 large Russet potatoes, peeled and quartered',
#     'originalName': 'Russet potatoes, peeled and quartered',
#     'meta': ['peeled', 'quartered'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/russet-or-idaho-potatoes.png'},
#    {'id': 1230,
#     'amount': 0.5,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': '1%%fat butter milk',
#     'original': '1/2 cup 1%%fat butter milk',
#     'originalName': '1%%fat butter milk',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/buttermilk.jpg'},
#    {'id': 2025,
#     'amount': 0.125,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'nutmeg',
#     'original': '1/8 teaspoon Grated nutmeg',
#     'originalName': 'Grated nutmeg',
#     'meta': ['grated'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/ground-nutmeg.jpg'},
#    {'id': 11282,
#     'amount': 2.0,
#     'unit': 'medium',
#     'unitLong': 'mediums',
#     'unitShort': 'medium',
#     'aisle': 'Produce',
#     'name': 'onions',
#     'original': '2 mediums Onions, peeled and sliced thin',
#     'originalName': 's Onions, peeled and sliced thin',
#     'meta': ['peeled', 'sliced', 'thin'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/brown-onion.png'},
#    {'id': 2016,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'dill seed',
#     'original': '1 teaspoon Dill seed',
#     'originalName': 'Dill seed',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/fennel-seeds.jpg'},
#    {'id': 2005,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'caraway seed',
#     'original': '1 teaspoon Caraway seed',
#     'originalName': 'Caraway seed',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/caraway-seeds.jpg'},
#    {'id': 2024,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'mustard seed',
#     'original': '1 teaspoon Yellow mustard seed',
#     'originalName': 'Yellow mustard seed',
#     'meta': ['yellow'],
#     'extendedName': 'yellow mustard seed',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/mustard-seeds.png'},
#    {'id': 1006970,
#     'amount': 1.0,
#     'unit': 'cup',
#     'unitLong': 'cup',
#     'unitShort': 'cup',
#     'aisle': 'Canned and Jarred',
#     'name': 'chicken stock',
#     'original': '1 cup Low sodium chicken stock',
#     'originalName': 'Low sodium chicken stock',
#     'meta': ['low sodium'],
#     'extendedName': 'low sodium chicken stock',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/img.spoonacular.'},
#    {'id': 14084,
#     'amount': 1.0,
#     'unit': 'cup',
#     'unitLong': 'cup',
#     'unitShort': 'cup',
#     'aisle': 'Alcoholic Beverages',
#     'name': 'de-alcoholised wine',
#     'original': '1 cup De-alcoholised dry red wine',
#     'originalName': 'De-alcoholised dry red wine',
#     'meta': ['dry red'],
#     'extendedName': 'dry red de-alcoholised wine',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/red-wine.jpg'},
#    {'id': 20003,
#     'amount': 1.0,
#     'unit': 'tablespoon',
#     'unitLong': 'tablespoon',
#     'unitShort': 'Tbsp',
#     'aisle': 'Baking',
#     'name': 'arrowroot',
#     'original': '1 tablespoon Arrowroot mixed with 2tbsp de-alcoholised, (slurry) red',
#     'originalName': 'Arrowroot mixed with 2tbsp de-alcoholised, (slurry) red',
#     'meta': ['mixed', 'with 2tbsp de-alcoholised, (slurry) red'],
#     'extendedName': 'mixed arrowroot',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/white-powder.jpg'},
#    {'id': 10511297,
#     'amount': 2.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'parsley',
#     'original': '2 tablespoons Chopped fresh parsley',
#     'originalName': 'Chopped fresh parsley',
#     'meta': ['fresh', 'chopped'],
#     'extendedName': 'fresh parsley',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/parsley.jpg'},
#    {'id': 99289,
#     'amount': 4.0,
#     'unit': 'teaspoons',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Condiments',
#     'name': 'mustard',
#     'original': '4 teaspoons Dry English mustard mixed with 4tsp',
#     'originalName': 'Dry English mustard mixed with 4tsp',
#     'meta': ['mixed', 'dry', 'english', 'with 4tsp'],
#     'extendedName': 'english dry mixed mustard',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/regular-mustard.jpg'}],
#   'usedIngredients': [{'id': 4542,
#     'amount': 3.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Meat',
#     'name': 'lower fat chicken-apple sausages',
#     'original': '3 Lower fat smoked chicken-apple sausages',
#     'originalName': 'Lower fat smoked chicken-apple sausages',
#     'meta': ['smoked'],
#     'extendedName': 'smoked lower fat chicken-apple sausages',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'},
#    {'id': 9003,
#     'amount': 4.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'apples',
#     'original': '4 Sweet apples, whole, cored, peel intact',
#     'originalName': 'Sweet apples, whole, cored, peel intact',
#     'meta': ['sweet', 'whole', 'cored'],
#     'extendedName': 'whole sweet apples',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'}],
#   'unusedIngredients': [],
#   'likes': 1},
#  {'id': 660261,
#   'title': 'Slow Cooked Applesauce',
#   'image': 'https://img.spoonacular.com/recipes/660261-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 2,
#   'missedIngredients': [{'id': 2010,
#     'amount': 0.5,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cinnamon',
#     'original': '1/2 teaspoon cinnamon',
#     'originalName': 'cinnamon',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/cinnamon.jpg'},
#    {'id': 2025,
#     'amount': 1.0,
#     'unit': 'pinch',
#     'unitLong': 'pinch',
#     'unitShort': 'pinch',
#     'aisle': 'Spices and Seasonings',
#     'name': 'nutmeg',
#     'original': 'pinch of nutmeg',
#     'originalName': 'pinch of nutmeg',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/ground-nutmeg.jpg'}],
#   'usedIngredients': [{'id': 9003,
#     'amount': 5.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'apples from a local tree if possible',
#     'original': '5 apples from a local tree if possible',
#     'originalName': 'apples from a local tree if possible',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 2},
#  {'id': 716433,
#   'title': 'Easiest Breakfast Ever: Sunny Fruit Parfait',
#   'image': 'https://img.spoonacular.com/recipes/716433-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 9299,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Dried Fruits',
#     'name': 'raisins',
#     'original': 'organic raisins',
#     'originalName': 'organic raisins',
#     'meta': ['organic'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/raisins.jpg'},
#    {'id': 12036,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Savory Snacks',
#     'name': 'sunflower seeds',
#     'original': 'sunflower seeds',
#     'originalName': 'sunflower seeds',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/sunflower-seeds.jpg'},
#    {'id': 1001116,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'yogurt',
#     'original': 'plain yogurt, unsweetened (regular or greek)',
#     'originalName': 'plain yogurt, unsweetened (regular or greek)',
#     'meta': ['plain', 'unsweetened', '(regular or greek)'],
#     'extendedName': 'unsweetened plain yogurt',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/plain-yogurt.jpg'}],
#   'usedIngredients': [{'id': 9003,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Produce',
#     'name': 'apple',
#     'original': 'chopped organic apple, unpeeled (grated instead of chopped for very small children)',
#     'originalName': 'chopped organic apple, unpeeled (grated instead of chopped for very small children)',
#     'meta': ['organic',
#      'grated',
#      'unpeeled',
#      'chopped',
#      'for very small children',
#      '( instead of )'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 93},
#  {'id': 633548,
#   'title': 'Baked Cinnamon Apple Wedges',
#   'image': 'https://img.spoonacular.com/recipes/633548-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 19911,
#     'amount': 1.0,
#     'unit': 'tsp',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Cereal',
#     'name': 'maple syrup',
#     'original': '1 tsp maple syrup',
#     'originalName': 'maple syrup',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/maple-syrup.png'},
#    {'id': 2010,
#     'amount': 0.5,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cinnamon',
#     'original': '1/2 tsp cinnamon',
#     'originalName': 'cinnamon',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/cinnamon.jpg'},
#    {'id': 2025,
#     'amount': 0.25,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'nutmeg',
#     'original': '1/4 tsp nutmeg',
#     'originalName': 'nutmeg',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/ground-nutmeg.jpg'}],
#   'usedIngredients': [{'id': 9003,
#     'amount': 1.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'apple',
#     'original': '1 apple',
#     'originalName': 'apple',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 2},
#  {'id': 662665,
#   'title': 'Swiss Bircher Muesli',
#   'image': 'https://img.spoonacular.com/recipes/662665-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 1077,
#     'amount': 0.5,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'milk',
#     'original': '1/2 cup of Milk',
#     'originalName': 'Milk',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/milk.png'},
#    {'id': 42184,
#     'amount': 0.5,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Cereal',
#     'name': 'muesli',
#     'original': '1/2 cup muesli',
#     'originalName': 'muesli',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/granola.jpg'},
#    {'id': 1119,
#     'amount': 3.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'vanilla yoghurt',
#     'original': '3 tablespoons of plain or vanilla yoghurt',
#     'originalName': 'plain or vanilla yoghurt',
#     'meta': ['plain'],
#     'extendedName': 'plain vanilla yoghurt',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/vanilla-yogurt.png'}],
#   'usedIngredients': [{'id': 9003,
#     'amount': 1.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'apple',
#     'original': '1 Apple',
#     'originalName': 'Apple',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 1},
#  {'id': 633547,
#   'title': 'Baked Cinnamon Apple Slice Snack',
#   'image': 'https://img.spoonacular.com/recipes/633547-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 2010,
#     'amount': 1.5,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cinnamon',
#     'original': '1 1/2 tablespoons of Cinnamon',
#     'originalName': 'Cinnamon',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/cinnamon.jpg'},
#    {'id': 9299,
#     'amount': 0.5,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Dried Fruits',
#     'name': 'raisins',
#     'original': '1/2 cup of Raisins',
#     'originalName': 'Raisins',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/raisins.jpg'},
#    {'id': 4073,
#     'amount': 2.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'margarine',
#     'original': '2 tablespoons of margarine',
#     'originalName': 'margarine',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/butter-sliced.jpg'}],
#   'usedIngredients': [{'id': 9003,
#     'amount': 4.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'apples',
#     'original': '4 Apples',
#     'originalName': 'Apples',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 1},
#  {'id': 662175,
#   'title': 'Sugar-Free Apple and Cinnamon Jam',
#   'image': 'https://img.spoonacular.com/recipes/662175-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 11663,
#     'amount': 0.5,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Health Foods',
#     'name': 'agar-agar powder',
#     'original': '1/2 teaspoon agar-agar powder',
#     'originalName': 'agar-agar powder',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/white-powder.jpg'},
#    {'id': 1012010,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cinnamon powder',
#     'original': '1 teaspoon cinnamon powder',
#     'originalName': 'cinnamon powder',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/cinnamon.jpg'},
#    {'id': 99292,
#     'amount': 1.5,
#     'unit': 'cups',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Health Foods',
#     'name': 'sweetener',
#     'original': '1 1/2 cups sweetener (I used Candarel)',
#     'originalName': 'sweetener (I used Candarel)',
#     'meta': ['(I used Candarel)'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/sugar-substitute.jpg'}],
#   'usedIngredients': [{'id': 9003,
#     'amount': 1.0,
#     'unit': 'medium',
#     'unitLong': 'medium',
#     'unitShort': 'medium',
#     'aisle': 'Produce',
#     'name': 'around 10 sized eating apples',
#     'original': 'medium Around 10 sized eating (not cooking) apples, peeled, cored and chopped into ½ inch pieces',
#     'originalName': 'Around 10 sized eating (not cooking) apples, peeled, cored and chopped into ½ inch pieces',
#     'meta': ['cored', 'peeled', 'chopped', '(not cooking)'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 1},
#  {'id': 663748,
#   'title': 'Traditional Apple Tart',
#   'image': 'https://img.spoonacular.com/recipes/663748-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 9083,
#     'amount': 4.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'blackcurrant jam',
#     'original': '4 tablespoons blackcurrant jam',
#     'originalName': 'blackcurrant jam',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/black-currants.png'},
#    {'id': 10018338,
#     'amount': 500.0,
#     'unit': 'grams',
#     'unitLong': 'grams',
#     'unitShort': 'g',
#     'aisle': 'Frozen',
#     'name': 'oz short crust pastry - ready made if you want',
#     'original': '500 grams 1lb 2oz short crust pastry – ready made if you want',
#     'originalName': '1lb 2oz short crust pastry – ready made if you want',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/dough.jpg'},
#    {'id': 1145,
#     'amount': 80.0,
#     'unit': 'grams',
#     'unitLong': 'grams',
#     'unitShort': 'g',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'butter',
#     'original': '80 grams 3oz unsalted butter',
#     'originalName': '3oz unsalted butter',
#     'meta': ['unsalted'],
#     'extendedName': 'unsalted butter',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/butter-sliced.jpg'}],
#   'usedIngredients': [{'id': 1089003,
#     'amount': 1.5,
#     'unit': 'pounds',
#     'unitLong': 'pounds',
#     'unitShort': 'lb',
#     'aisle': 'Produce',
#     'name': 'granny smiths',
#     'original': '1 1/2 pounds 3 cooking apples such as Bramley or Granny Smiths',
#     'originalName': '3 cooking apples such as Bramley or Granny Smiths',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/grannysmith-apple.png'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 1},
#  {'id': 636835,
#   'title': 'Canadian apple butter',
#   'image': 'https://img.spoonacular.com/recipes/636835-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 1,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 19911,
#     'amount': 2.0,
#     'unit': 'tbsp',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Cereal',
#     'name': 'brown sugar',
#     'original': '2 tbsp brown sugar (you can also use maple syrup or sugar, or honey)',
#     'originalName': 'brown sugar (you can also use maple syrup or sugar, or honey)',
#     'meta': ['canned', '(you can also use maple syrup or sugar, or honey)'],
#     'extendedName': 'canned brown sugar',
#     'image': 'https://img.spoonacular.com/ingredients_100x100/maple-syrup.png'},
#    {'id': 93812,
#     'amount': 0.25,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Gourmet',
#     'name': 'vanilla powder',
#     'original': '¼ tsp vanilla powder',
#     'originalName': 'vanilla powder',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/vanilla-sugar.jpg'},
#    {'id': 2010,
#     'amount': 1.0,
#     'unit': 'pinch',
#     'unitLong': 'pinch',
#     'unitShort': 'pinch',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cinnamon',
#     'original': '1 pinch cinnamon',
#     'originalName': 'cinnamon',
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/cinnamon.jpg'}],
#   'usedIngredients': [{'id': 9003,
#     'amount': 850.0,
#     'unit': 'g',
#     'unitLong': 'grams',
#     'unitShort': 'g',
#     'aisle': 'Produce',
#     'name': 'apples',
#     'original': '850g /30 oz. apples (about 3-4)',
#     'originalName': '30 oz. apples (about 3-4)',
#     'meta': ['( 3-4)'],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'}],
#   'unusedIngredients': [{'id': 4542,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Meat',
#     'name': "chicken']",
#     'original': "'chicken']",
#     'originalName': "chicken']",
#     'meta': [],
#     'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#   'likes': 1}]

# %%
ingredients_json[0]
# Out:
# {'id': 673463,
#  'title': 'Slow Cooker Apple Pork Tenderloin',
#  'image': 'https://img.spoonacular.com/recipes/673463-312x231.jpg',
#  'imageType': 'jpg',
#  'usedIngredientCount': 2,
#  'missedIngredientCount': 2,
#  'missedIngredients': [{'id': 6008,
#    'amount': 2.0,
#    'unit': 'cups',
#    'unitLong': 'cups',
#    'unitShort': 'cup',
#    'aisle': 'Canned and Jarred',
#    'name': 'beef broth',
#    'original': '2 cups beef broth',
#    'originalName': 'beef broth',
#    'meta': [],
#    'image': 'https://img.spoonacular.com/ingredients_100x100/beef-broth.png'},
#   {'id': 10218,
#    'amount': 1.0,
#    'unit': 'serving',
#    'unitLong': 'serving',
#    'unitShort': 'serving',
#    'aisle': 'Meat',
#    'name': 'pork tenderloin',
#    'original': 'Pork Tenderloin',
#    'originalName': 'Pork Tenderloin',
#    'meta': [],
#    'image': 'https://img.spoonacular.com/ingredients_100x100/pork-tenderloin-raw.png'}],
#  'usedIngredients': [{'id': 9003,
#    'amount': 1.0,
#    'unit': 'serving',
#    'unitLong': 'serving',
#    'unitShort': 'serving',
#    'aisle': 'Produce',
#    'name': 'apple r',
#    'original': 'apple slicer (*optional)',
#    'originalName': 'apple slicer (*optional)',
#    'meta': ['(*optional)'],
#    'image': 'https://img.spoonacular.com/ingredients_100x100/apple.jpg'},
#   {'id': 1069003,
#    'amount': 2.0,
#    'unit': '',
#    'unitLong': '',
#    'unitShort': '',
#    'aisle': 'Produce',
#    'name': 'apples',
#    'original': '2 green apples',
#    'originalName': 'green apples',
#    'meta': ['green'],
#    'extendedName': 'green apples',
#    'image': 'https://img.spoonacular.com/ingredients_100x100/grannysmith-apple.png'}],
#  'unusedIngredients': [{'id': 4542,
#    'amount': 1.0,
#    'unit': 'serving',
#    'unitLong': 'serving',
#    'unitShort': 'serving',
#    'aisle': 'Meat',
#    'name': "chicken']",
#    'original': "'chicken']",
#    'originalName': "chicken']",
#    'meta': [],
#    'image': 'https://img.spoonacular.com/ingredients_100x100/lard.png'}],
#  'likes': 0}

# %%
results = {}
key = "5cb09004fe27449689868405b5a33789"

for recipe in ingredients_json:
    id_num = recipe["id"]
    recipe_info = requests.get(f"https://api.spoonacular.com/recipes/{id_num}/information?apiKey={key}").json()
    recipe_name = recipe_info["title"]
    # recipe_summary = recipe_info["summary"]
    recipe_pic = recipe_info["image"]
    recipe_time = recipe_info["readyInMinutes"]
    recipe_source = recipe_info["sourceUrl"]
    recipe_diets = recipe_info["diets"]
    if recipe_info["cuisines"]:
        recipe_cuisine = recipe_info["cuisines"]
    else:
        recipe_cuisine = "No cuisine defined!"
    ingredients_list = []
    for i in recipe_info["extendedIngredients"]:
        ingredient_name = i["nameClean"]
        ingredients_list.append(ingredient_name)
    results[recipe_name] = [recipe_time, recipe_pic, recipe_diets, recipe_cuisine, ingredients_list, recipe_source]

print(results)
# Out:
# {'Slow Cooker Apple Pork Tenderloin': [45, 'https://img.spoonacular.com/recipes/673463-556x370.jpg', ['gluten free', 'dairy free'], 'No cuisine defined!', ['apple', 'beef broth', 'cinnamon sugar', 'green apple', 'pork tenderloin'], 'http://www.pinkwhen.com/slow-cooker-apple-pork-tenderloin/'], 'Bangers and Mash': [45, 'https://img.spoonacular.com/recipes/44789-556x370.jpg', ['gluten free'], 'No cuisine defined!', ['chicken fat', 'apple', 'rutabaga', 'russet potato', 'coarse sea salt', 'buttermilk', 'nutmeg', 'white pepper', 'light olive oil', 'onion', 'dill seed', 'caraway seeds', 'yellow mustard seeds', 'apple', 'low sodium chicken stock', 'wine', 'arrowroot', 'fresh parsley', 'english mustard'], 'https://www.foodista.com/recipe/78FLMC4R/bangers-and-mash'], 'Slow Cooked Applesauce': [45, 'https://img.spoonacular.com/recipes/660261-556x370.jpg', ['gluten free', 'dairy free', 'lacto ovo vegetarian', 'vegan'], 'No cuisine defined!', ['apple', 'water', 'golden brown sugar', 'cinnamon', 'nutmeg', 'table salt'], 'https://www.foodista.com/recipe/XB3V6NRQ/slow-cooked-applesauce'], 'Easiest Breakfast Ever: Sunny Fruit Parfait': [45, 'https://img.spoonacular.com/recipes/716433-556x370.jpg', ['gluten free', 'lacto ovo vegetarian', 'primal'], 'No cuisine defined!', ['apple', 'raisins', 'sunflower seeds', 'plain yogurt'], 'http://fullbellysisters.blogspot.com/2011/04/easiest-breakfast-ever-sunny-fruit.html'], 'Baked Cinnamon Apple Wedges': [45, 'https://img.spoonacular.com/recipes/633548-556x370.jpg', ['gluten free', 'dairy free', 'paleolithic', 'lacto ovo vegetarian', 'primal', 'vegan'], 'No cuisine defined!', ['apple', 'maple syrup', 'cinnamon', 'nutmeg'], 'https://www.foodista.com/recipe/XJ3WCV8B/baked-cinnamon-apple-wedges'], 'Swiss Bircher Muesli': [45, 'https://img.spoonacular.com/recipes/662665-556x370.jpg', ['lacto ovo vegetarian'], 'No cuisine defined!', ['apple', 'milk', 'muesli', 'vanilla yogurt'], 'https://www.foodista.com/recipe/PXSGNFC6/swiss-bircher-muesli'], 'Baked Cinnamon Apple Slice Snack': [40, 'https://img.spoonacular.com/recipes/633547-556x370.jpg', ['gluten free', 'dairy free', 'whole 30'], 'No cuisine defined!', ['apple', 'cinnamon', 'raisins', 'margarine'], 'https://www.foodista.com/recipe/JQWGC7VW/baked-cinnamon-apple-slices'], 'Sugar-Free Apple and Cinnamon Jam': [45, 'https://img.spoonacular.com/recipes/662175-556x370.jpg', ['gluten free', 'dairy free', 'lacto ovo vegetarian', 'vegan'], 'No cuisine defined!', ['agar', 'apple', 'ground cinnamon', 'sola sweetener', 'water'], 'https://www.foodista.com/recipe/5TRTLPS2/sugar-free-apple-and-cinnamon-jam'], 'Traditional Apple Tart': [45, 'https://img.spoonacular.com/recipes/663748-556x370.jpg', ['lacto ovo vegetarian'], 'No cuisine defined!', ['granny smith apple', 'black currants', 'shortcrust pastry', 'sugar', 'unsalted butter'], 'https://www.foodista.com/recipe/M23CKJZX/traditional-apple-tart'], 'Canadian apple butter': [45, 'https://img.spoonacular.com/recipes/636835-556x370.jpg', ['gluten free', 'dairy free', 'paleolithic', 'lacto ovo vegetarian', 'primal', 'vegan'], 'No cuisine defined!', ['apple', 'maple syrup', 'vanilla powder', 'cinnamon', 'coconut oil'], 'https://www.foodista.com/recipe/85YGRVYJ/canadian-apple-butter']}

# %%
key = "5cb09004fe27449689868405b5a33789"
recipe_info = requests.get(f"https://api.spoonacular.com/recipes/673463/information?apiKey={key}").json()
recipe_info
# Out:
# {'id': 673463,
#  'image': 'https://img.spoonacular.com/recipes/673463-556x370.jpg',
#  'imageType': 'jpg',
#  'title': 'Slow Cooker Apple Pork Tenderloin',
#  'readyInMinutes': 45,
#  'servings': 1,
#  'sourceUrl': 'http://www.pinkwhen.com/slow-cooker-apple-pork-tenderloin/',
#  'vegetarian': False,
#  'vegan': False,
#  'glutenFree': True,
#  'dairyFree': True,
#  'veryHealthy': False,
#  'cheap': False,
#  'veryPopular': False,
#  'sustainable': False,
#  'lowFodmap': False,
#  'weightWatcherSmartPoints': 6,
#  'gaps': 'no',
#  'preparationMinutes': None,
#  'cookingMinutes': None,
#  'aggregateLikes': 0,
#  'healthScore': 18.0,
#  'creditsText': 'Jen West',
#  'license': None,
#  'sourceName': 'Pink When',
#  'pricePerServing': 440.93,
#  'extendedIngredients': [{'id': 9003,
#    'aisle': 'Produce',
#    'image': 'apple.jpg',
#    'consistency': 'SOLID',
#    'name': 'apple r',
#    'nameClean': 'apple',
#    'original': 'apple slicer (*optional)',
#    'originalName': 'apple slicer (*optional)',
#    'amount': 1.0,
#    'unit': 'serving',
#    'meta': ['(*optional)'],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'serving',
#      'unitLong': 'serving'},
#     'metric': {'amount': 1.0, 'unitShort': 'serving', 'unitLong': 'serving'}}},
#   {'id': 6008,
#    'aisle': 'Canned and Jarred',
#    'image': 'beef-broth.png',
#    'consistency': 'LIQUID',
#    'name': 'beef broth',
#    'nameClean': 'beef broth',
#    'original': '2 cups beef broth',
#    'originalName': 'beef broth',
#    'amount': 2.0,
#    'unit': 'cups',
#    'meta': [],
#    'measures': {'us': {'amount': 2.0, 'unitShort': 'cups', 'unitLong': 'cups'},
#     'metric': {'amount': 480.0,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 10219335,
#    'aisle': 'Spices and Seasonings',
#    'image': 'cinnamon-sugar.png',
#    'consistency': 'SOLID',
#    'name': 'cinnamon sugar',
#    'nameClean': 'cinnamon sugar',
#    'original': 'cinnamon sugar (*optional)',
#    'originalName': 'cinnamon sugar (*optional)',
#    'amount': 1.0,
#    'unit': 'serving',
#    'meta': ['(*optional)'],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'serving',
#      'unitLong': 'serving'},
#     'metric': {'amount': 1.0, 'unitShort': 'serving', 'unitLong': 'serving'}}},
#   {'id': 1069003,
#    'aisle': 'Produce',
#    'image': 'grannysmith-apple.png',
#    'consistency': 'SOLID',
#    'name': 'apples',
#    'nameClean': 'green apple',
#    'original': '2 green apples',
#    'originalName': 'green apples',
#    'amount': 2.0,
#    'unit': '',
#    'meta': ['green'],
#    'measures': {'us': {'amount': 2.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 2.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 10218,
#    'aisle': 'Meat',
#    'image': 'pork-tenderloin-raw.png',
#    'consistency': 'SOLID',
#    'name': 'pork tenderloin',
#    'nameClean': 'pork tenderloin',
#    'original': 'Pork Tenderloin',
#    'originalName': 'Pork Tenderloin',
#    'amount': 1.0,
#    'unit': 'serving',
#    'meta': [],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'serving',
#      'unitLong': 'serving'},
#     'metric': {'amount': 1.0,
#      'unitShort': 'serving',
#      'unitLong': 'serving'}}}],
#  'summary': 'You can never have too many main course recipes, so give Slow Cooker Apple Pork Tenderloin a try. This recipe serves 1 and costs $4.41 per serving. One portion of this dish contains around <b>34g of protein</b>, <b>7g of fat</b>, and a total of <b>462 calories</b>. Head to the store and pick up apples, beef broth, pork tenderloin, and a few other things to make it today. This recipe from Pink When has 1 fans. From preparation to the plate, this recipe takes about <b>45 minutes</b>. It is a good option if you\'re following a <b>gluten free and dairy free</b> diet. Overall, this recipe earns a <b>solid spoonacular score of 57%</b>. Users who liked this recipe also liked <a href="https://spoonacular.com/recipes/slow-cooker-apple-pork-tenderloin-1614071">Slow Cooker Apple Pork Tenderloin</a>, <a href="https://spoonacular.com/recipes/slow-cooker-pork-tenderloin-143861">Slow Cooker Pork Tenderloin</a>, and <a href="https://spoonacular.com/recipes/amazing-pork-tenderloin-in-the-slow-cooker-143478">Amazing Pork Tenderloin in the Slow Cooker</a>.',
#  'cuisines': [],
#  'dishTypes': ['lunch', 'main course', 'main dish', 'dinner'],
#  'diets': ['gluten free', 'dairy free'],
#  'occasions': [],
#  'instructions': None,
#  'analyzedInstructions': [],
#  'originalId': None,
#  'spoonacularScore': 19.933595657348633,
#  'spoonacularSourceUrl': 'https://spoonacular.com/slow-cooker-apple-pork-tenderloin-673463'}

# %%
ingredients_list = []
for key in recipe_info["extendedIngredients"]:
    ingredient_name = key["nameClean"]
    ingredients_list.append(ingredient_name)

print(ingredients_list)
# Out:
# ['apple', 'maple syrup', 'vanilla powder', 'cinnamon', 'coconut oil']

# %%
key = "5cb09004fe27449689868405b5a33789"
pricetest = requests.get(f"https://api.spoonacular.com/recipes/673463/priceBreakdownWidget.json?apiKey={key}").json()
pricetest
# Out:
# {'ingredients': [{'name': 'apple r',
#    'image': 'apple.jpg',
#    'price': 20.69,
#    'amount': {'metric': {'value': 1.0, 'unit': 'serving'},
#     'us': {'value': 1.0, 'unit': 'serving'}}},
#   {'name': 'beef broth',
#    'image': 'beef-broth.png',
#    'price': 113.9,
#    'amount': {'metric': {'value': 480.0, 'unit': 'ml'},
#     'us': {'value': 2.0, 'unit': 'cups'}}},
#   {'name': 'cinnamon sugar',
#    'image': 'cinnamon-sugar.png',
#    'price': 41.14,
#    'amount': {'metric': {'value': 1.0, 'unit': 'serving'},
#     'us': {'value': 1.0, 'unit': 'serving'}}},
#   {'name': 'green apples',
#    'image': 'grannysmith-apple.png',
#    'price': 160.97,
#    'amount': {'metric': {'value': 2.0, 'unit': ''},
#     'us': {'value': 2.0, 'unit': ''}}},
#   {'name': 'pork tenderloin',
#    'image': 'pork-tenderloin-raw.png',
#    'price': 104.22,
#    'amount': {'metric': {'value': 1.0, 'unit': 'serving'},
#     'us': {'value': 1.0, 'unit': 'serving'}}}],
#  'totalCost': 440.93,
#  'totalCostPerServing': 440.93}

# %%
key = "5cb09004fe27449689868405b5a33789"
recipe_test = requests.get(f"https://api.spoonacular.com/recipes/44789/information?apiKey={key}").json()
recipe_test
# Out:
# {'id': 44789,
#  'image': 'https://img.spoonacular.com/recipes/44789-556x370.jpg',
#  'imageType': 'jpg',
#  'title': 'Bangers and Mash',
#  'readyInMinutes': 45,
#  'servings': 1,
#  'sourceUrl': 'https://www.foodista.com/recipe/78FLMC4R/bangers-and-mash',
#  'vegetarian': False,
#  'vegan': False,
#  'glutenFree': True,
#  'dairyFree': False,
#  'veryHealthy': True,
#  'cheap': False,
#  'veryPopular': False,
#  'sustainable': False,
#  'lowFodmap': False,
#  'weightWatcherSmartPoints': 52,
#  'gaps': 'no',
#  'preparationMinutes': None,
#  'cookingMinutes': None,
#  'aggregateLikes': 1,
#  'healthScore': 100.0,
#  'creditsText': 'Foodista.com – The Cooking Encyclopedia Everyone Can Edit',
#  'license': 'CC BY 3.0',
#  'sourceName': 'Foodista',
#  'pricePerServing': 1366.94,
#  'extendedIngredients': [{'id': 4542,
#    'aisle': 'Meat',
#    'image': 'lard.png',
#    'consistency': 'SOLID',
#    'name': 'lower fat chicken-apple sausages',
#    'nameClean': 'chicken fat',
#    'original': '3 Lower fat smoked chicken-apple sausages',
#    'originalName': 'Lower fat smoked chicken-apple sausages',
#    'amount': 3.0,
#    'unit': '',
#    'meta': ['smoked'],
#    'measures': {'us': {'amount': 3.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 3.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 9003,
#    'aisle': 'Produce',
#    'image': 'apple.jpg',
#    'consistency': 'SOLID',
#    'name': 'apples',
#    'nameClean': 'apple',
#    'original': '4 Sweet apples, whole, cored, peel intact',
#    'originalName': 'Sweet apples, whole, cored, peel intact',
#    'amount': 4.0,
#    'unit': '',
#    'meta': ['sweet', 'whole', 'cored'],
#    'measures': {'us': {'amount': 4.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 4.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 11435,
#    'aisle': 'Produce',
#    'image': 'rutabaga.jpg',
#    'consistency': 'SOLID',
#    'name': 'rutabagas',
#    'nameClean': 'rutabaga',
#    'original': '4 mediums Rutabagas, peeled and quartered',
#    'originalName': 's Rutabagas, peeled and quartered',
#    'amount': 4.0,
#    'unit': 'medium',
#    'meta': ['peeled', 'quartered'],
#    'measures': {'us': {'amount': 4.0,
#      'unitShort': 'medium',
#      'unitLong': 'mediums'},
#     'metric': {'amount': 4.0, 'unitShort': 'medium', 'unitLong': 'mediums'}}},
#   {'id': 11353,
#    'aisle': 'Produce',
#    'image': 'russet-or-idaho-potatoes.png',
#    'consistency': 'SOLID',
#    'name': 'russet potatoes',
#    'nameClean': 'russet potato',
#    'original': '4 large Russet potatoes, peeled and quartered',
#    'originalName': 'Russet potatoes, peeled and quartered',
#    'amount': 4.0,
#    'unit': 'large',
#    'meta': ['peeled', 'quartered'],
#    'measures': {'us': {'amount': 4.0,
#      'unitShort': 'large',
#      'unitLong': 'larges'},
#     'metric': {'amount': 4.0, 'unitShort': 'large', 'unitLong': 'larges'}}},
#   {'id': 1012047,
#    'aisle': 'Spices and Seasonings',
#    'image': 'salt.jpg',
#    'consistency': 'SOLID',
#    'name': 'ground sea salt',
#    'nameClean': 'coarse sea salt',
#    'original': '1/2 teaspoon Finely ground sea salt',
#    'originalName': 'Finely ground sea salt',
#    'amount': 0.5,
#    'unit': 'teaspoon',
#    'meta': ['finely'],
#    'measures': {'us': {'amount': 0.5,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'},
#     'metric': {'amount': 0.5, 'unitShort': 'tsps', 'unitLong': 'teaspoons'}}},
#   {'id': 1230,
#    'aisle': 'Milk, Eggs, Other Dairy',
#    'image': 'buttermilk.jpg',
#    'consistency': 'SOLID',
#    'name': '1%%fat butter milk',
#    'nameClean': 'buttermilk',
#    'original': '1/2 cup 1%%fat butter milk',
#    'originalName': '1%%fat butter milk',
#    'amount': 0.5,
#    'unit': 'cup',
#    'meta': [],
#    'measures': {'us': {'amount': 0.5, 'unitShort': 'cups', 'unitLong': 'cups'},
#     'metric': {'amount': 120.0,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 2025,
#    'aisle': 'Spices and Seasonings',
#    'image': 'ground-nutmeg.jpg',
#    'consistency': 'SOLID',
#    'name': 'nutmeg',
#    'nameClean': 'nutmeg',
#    'original': '1/8 teaspoon Grated nutmeg',
#    'originalName': 'Grated nutmeg',
#    'amount': 0.125,
#    'unit': 'teaspoon',
#    'meta': ['grated'],
#    'measures': {'us': {'amount': 0.125,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'},
#     'metric': {'amount': 0.125,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'}}},
#   {'id': 2032,
#    'aisle': 'Spices and Seasonings',
#    'image': 'white-pepper.png',
#    'consistency': 'SOLID',
#    'name': 'pepper',
#    'nameClean': 'white pepper',
#    'original': '1/8 teaspoon Freshly ground white pepper',
#    'originalName': 'Freshly ground white pepper',
#    'amount': 0.125,
#    'unit': 'teaspoon',
#    'meta': ['white', 'freshly ground'],
#    'measures': {'us': {'amount': 0.125,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'},
#     'metric': {'amount': 0.125,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'}}},
#   {'id': 1054053,
#    'aisle': 'Oil, Vinegar, Salad Dressing',
#    'image': 'olive-oil.jpg',
#    'consistency': 'LIQUID',
#    'name': 'olive oil',
#    'nameClean': 'light olive oil',
#    'original': '1 teaspoon Light olive oil with a dash of toasted sesame oil',
#    'originalName': 'Light olive oil with a dash of toasted sesame oil',
#    'amount': 1.0,
#    'unit': 'teaspoon',
#    'meta': ['light', 'with a dash of toasted sesame oil'],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'tsp',
#      'unitLong': 'teaspoon'},
#     'metric': {'amount': 1.0, 'unitShort': 'tsp', 'unitLong': 'teaspoon'}}},
#   {'id': 11282,
#    'aisle': 'Produce',
#    'image': 'brown-onion.png',
#    'consistency': 'SOLID',
#    'name': 'onions',
#    'nameClean': 'onion',
#    'original': '2 mediums Onions, peeled and sliced thin',
#    'originalName': 's Onions, peeled and sliced thin',
#    'amount': 2.0,
#    'unit': 'medium',
#    'meta': ['peeled', 'sliced', 'thin'],
#    'measures': {'us': {'amount': 2.0,
#      'unitShort': 'medium',
#      'unitLong': 'mediums'},
#     'metric': {'amount': 2.0, 'unitShort': 'medium', 'unitLong': 'mediums'}}},
#   {'id': 2016,
#    'aisle': 'Spices and Seasonings',
#    'image': 'fennel-seeds.jpg',
#    'consistency': 'SOLID',
#    'name': 'dill seed',
#    'nameClean': 'dill seed',
#    'original': '1 teaspoon Dill seed',
#    'originalName': 'Dill seed',
#    'amount': 1.0,
#    'unit': 'teaspoon',
#    'meta': [],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'tsp',
#      'unitLong': 'teaspoon'},
#     'metric': {'amount': 1.0, 'unitShort': 'tsp', 'unitLong': 'teaspoon'}}},
#   {'id': 2005,
#    'aisle': 'Spices and Seasonings',
#    'image': 'caraway-seeds.jpg',
#    'consistency': 'SOLID',
#    'name': 'caraway seed',
#    'nameClean': 'caraway seeds',
#    'original': '1 teaspoon Caraway seed',
#    'originalName': 'Caraway seed',
#    'amount': 1.0,
#    'unit': 'teaspoon',
#    'meta': [],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'tsp',
#      'unitLong': 'teaspoon'},
#     'metric': {'amount': 1.0, 'unitShort': 'tsp', 'unitLong': 'teaspoon'}}},
#   {'id': 2024,
#    'aisle': 'Spices and Seasonings',
#    'image': 'mustard-seeds.png',
#    'consistency': 'SOLID',
#    'name': 'mustard seed',
#    'nameClean': 'yellow mustard seeds',
#    'original': '1 teaspoon Yellow mustard seed',
#    'originalName': 'Yellow mustard seed',
#    'amount': 1.0,
#    'unit': 'teaspoon',
#    'meta': ['yellow'],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'tsp',
#      'unitLong': 'teaspoon'},
#     'metric': {'amount': 1.0, 'unitShort': 'tsp', 'unitLong': 'teaspoon'}}},
#   {'id': 9003,
#    'aisle': 'Produce',
#    'image': 'apple.jpg',
#    'consistency': 'SOLID',
#    'name': 'apple',
#    'nameClean': 'apple',
#    'original': '1 Sweet apple, peeled, cored, and sliced',
#    'originalName': 'Sweet apple, peeled, cored, and sliced',
#    'amount': 1.0,
#    'unit': '',
#    'meta': ['sweet', 'cored', 'peeled', 'sliced'],
#    'measures': {'us': {'amount': 1.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 1.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 1006970,
#    'aisle': 'Canned and Jarred',
#    'image': 'img.spoonacular.',
#    'consistency': 'SOLID',
#    'name': 'chicken stock',
#    'nameClean': 'low sodium chicken stock',
#    'original': '1 cup Low sodium chicken stock',
#    'originalName': 'Low sodium chicken stock',
#    'amount': 1.0,
#    'unit': 'cup',
#    'meta': ['low sodium'],
#    'measures': {'us': {'amount': 1.0, 'unitShort': 'cup', 'unitLong': 'cup'},
#     'metric': {'amount': 236.0,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 14084,
#    'aisle': 'Alcoholic Beverages',
#    'image': 'red-wine.jpg',
#    'consistency': 'LIQUID',
#    'name': 'de-alcoholised wine',
#    'nameClean': 'wine',
#    'original': '1 cup De-alcoholised dry red wine',
#    'originalName': 'De-alcoholised dry red wine',
#    'amount': 1.0,
#    'unit': 'cup',
#    'meta': ['dry red'],
#    'measures': {'us': {'amount': 1.0, 'unitShort': 'cup', 'unitLong': 'cup'},
#     'metric': {'amount': 240.0,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 20003,
#    'aisle': 'Baking',
#    'image': 'white-powder.jpg',
#    'consistency': 'SOLID',
#    'name': 'arrowroot',
#    'nameClean': 'arrowroot',
#    'original': '1 tablespoon Arrowroot mixed with 2tbsp de-alcoholised, (slurry) red',
#    'originalName': 'Arrowroot mixed with 2tbsp de-alcoholised, (slurry) red',
#    'amount': 1.0,
#    'unit': 'tablespoon',
#    'meta': ['mixed', 'with 2tbsp de-alcoholised, (slurry) red'],
#    'measures': {'us': {'amount': 1.0, 'unitShort': 'Tbsp', 'unitLong': 'Tbsp'},
#     'metric': {'amount': 1.0, 'unitShort': 'Tbsp', 'unitLong': 'Tbsp'}}},
#   {'id': 10511297,
#    'aisle': 'Produce',
#    'image': 'parsley.jpg',
#    'consistency': 'SOLID',
#    'name': 'parsley',
#    'nameClean': 'fresh parsley',
#    'original': '2 tablespoons Chopped fresh parsley',
#    'originalName': 'Chopped fresh parsley',
#    'amount': 2.0,
#    'unit': 'tablespoons',
#    'meta': ['fresh', 'chopped'],
#    'measures': {'us': {'amount': 2.0,
#      'unitShort': 'Tbsps',
#      'unitLong': 'Tbsps'},
#     'metric': {'amount': 2.0, 'unitShort': 'Tbsps', 'unitLong': 'Tbsps'}}},
#   {'id': 99289,
#    'aisle': 'Condiments',
#    'image': 'regular-mustard.jpg',
#    'consistency': 'LIQUID',
#    'name': 'mustard',
#    'nameClean': 'english mustard',
#    'original': '4 teaspoons Dry English mustard mixed with 4tsp',
#    'originalName': 'Dry English mustard mixed with 4tsp',
#    'amount': 4.0,
#    'unit': 'teaspoons',
#    'meta': ['mixed', 'dry', 'english', 'with 4tsp'],
#    'measures': {'us': {'amount': 4.0,
#      'unitShort': 'tsps',
#      'unitLong': 'teaspoons'},
#     'metric': {'amount': 4.0, 'unitShort': 'tsps', 'unitLong': 'teaspoons'}}}],
#  'summary': 'Bangers and Mash could be just the <b>gluten free</b> recipe you\'ve been looking for. This recipe serves 1 and costs $13.67 per serving. One portion of this dish contains about <b>65g of protein</b>, <b>22g of fat</b>, and a total of <b>2773 calories</b>. This recipe from Foodista requires lower fat chicken-apple sausages, nutmeg, onions, and chicken stock. 1 person were glad they tried this recipe. Not a lot of people really liked this side dish. From preparation to the plate, this recipe takes around <b>45 minutes</b>. Taking all factors into account, this recipe <b>earns a spoonacular score of 0%</b>, which is improvable. <a href="https://spoonacular.com/recipes/healthier-bangers-and-mash-646417">Healthier Bangers and Mash</a>, <a href="https://spoonacular.com/recipes/herb-chicken-with-sweet-potato-mash-and-sauted-broccoli-646651">Herb chicken with sweet potato mash and sautéed broccoli</a>, and <a href="https://spoonacular.com/recipes/strip-steak-with-roasted-cherry-tomatoes-and-vegetable-mash-661948">Strip steak with roasted cherry tomatoes and vegetable mash</a> are very similar to this recipe.',
#  'cuisines': [],
#  'dishTypes': ['side dish'],
#  'diets': ['gluten free'],
#  'occasions': [],
#  'instructions': 'Preheat the oven to 180C. Place the sausages and apples together on a shallow baking pan and bake for 30 minutes. Remove the peel from the apples and mash three reserving one for the sauce below.\nIn a medium saucepan, boil the rutabagas in water to cover for 30 minutes. Drain, return to the same pot, and mash until smooth.\nIn another medium saucepan, bring the potatoes to the boil in water, add 1/4tsp of the salt and cook for 20 minutes. Drain, return to the same pot and place over a very low heat, cover with a kitchen towel and let steam dry for 15 minutes. Mash the boiled potatoes with the buttermilk, nutmeg, white pepper and the remaining 1/4tsp salt until smooth.\nFor the brown onion sauce, while the bangers and mash are cooking, heat the oil in a high-sided skillet on medium high heat, add the onions, dill, caraway and mustard seed and cook, uncovered, 5 minutes without stirring. Add the sliced apple, stir once, cover and cook for 5 minutes.\nPour in the stock and wine, stirring and scraping all the pan residues up into the liquid until the bottom of the pan is perfectly clean, and simmer 5 minutes. Remove from the heat, stir in the arrowroot slurry, return to the heat, and bring to a boil to thicken, about 30 seconds. Mash the reserved baked apple, stir into the sauce, and set aside.\nTo serve place one scoop each of the mashed potatoes, apple and rutabaga down the centre of each serving plate. Slice each sausage into quarters lengthways. Ladle some sauce on one side of the mash and top the sauce with three quarters of sausage. Spoon some peas on the other side of the mash. Garnish with parsley and a tablespoon of the mustard mixture next to the sausage.',
#  'analyzedInstructions': [{'name': '',
#    'steps': [{'number': 1,
#      'step': 'Preheat the oven to 180C.',
#      'ingredients': [],
#      'equipment': [{'id': 404784,
#        'name': 'oven',
#        'localizedName': 'oven',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/oven.jpg',
#        'temperature': {'number': 180.0, 'unit': 'Celsius'}}]},
#     {'number': 2,
#      'step': 'Place the sausages and apples together on a shallow baking pan and bake for 30 minutes.',
#      'ingredients': [{'id': 1017063,
#        'name': 'sausage',
#        'localizedName': 'sausage',
#        'image': 'raw-pork-sausage.png'},
#       {'id': 9003,
#        'name': 'apple',
#        'localizedName': 'apple',
#        'image': 'https://spoonacular.com/cdn/ingredients_100x100/apple.jpg'}],
#      'equipment': [{'id': 404646,
#        'name': 'baking pan',
#        'localizedName': 'baking pan',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/roasting-pan.jpg'},
#       {'id': 404784,
#        'name': 'oven',
#        'localizedName': 'oven',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/oven.jpg'}],
#      'length': {'number': 30, 'unit': 'minutes'}},
#     {'number': 3,
#      'step': 'Remove the peel from the apples and mash three reserving one for the sauce below.',
#      'ingredients': [{'id': 9003,
#        'name': 'apple',
#        'localizedName': 'apple',
#        'image': 'https://spoonacular.com/cdn/ingredients_100x100/apple.jpg'},
#       {'id': 0, 'name': 'sauce', 'localizedName': 'sauce', 'image': ''}],
#      'equipment': []},
#     {'number': 4,
#      'step': 'In a medium saucepan, boil the rutabagas in water to cover for 30 minutes.',
#      'ingredients': [{'id': 11435,
#        'name': 'rutabaga',
#        'localizedName': 'rutabaga',
#        'image': 'rutabaga.jpg'},
#       {'id': 14412,
#        'name': 'water',
#        'localizedName': 'water',
#        'image': 'water.png'}],
#      'equipment': [{'id': 404669,
#        'name': 'sauce pan',
#        'localizedName': 'sauce pan',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/sauce-pan.jpg'}],
#      'length': {'number': 30, 'unit': 'minutes'}},
#     {'number': 5,
#      'step': 'Drain, return to the same pot, and mash until smooth.',
#      'ingredients': [],
#      'equipment': [{'id': 404752,
#        'name': 'pot',
#        'localizedName': 'pot',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/stock-pot.jpg'}]},
#     {'number': 6,
#      'step': 'In another medium saucepan, bring the potatoes to the boil in water, add 1/4tsp of the salt and cook for 20 minutes.',
#      'ingredients': [{'id': 11352,
#        'name': 'potato',
#        'localizedName': 'potato',
#        'image': 'potatoes-yukon-gold.png'},
#       {'id': 14412,
#        'name': 'water',
#        'localizedName': 'water',
#        'image': 'water.png'},
#       {'id': 2047,
#        'name': 'salt',
#        'localizedName': 'salt',
#        'image': 'salt.jpg'}],
#      'equipment': [{'id': 404669,
#        'name': 'sauce pan',
#        'localizedName': 'sauce pan',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/sauce-pan.jpg'}],
#      'length': {'number': 20, 'unit': 'minutes'}},
#     {'number': 7,
#      'step': 'Drain, return to the same pot and place over a very low heat, cover with a kitchen towel and let steam dry for 15 minutes. Mash the boiled potatoes with the buttermilk, nutmeg, white pepper and the remaining 1/4tsp salt until smooth.',
#      'ingredients': [{'id': 2032,
#        'name': 'white pepper',
#        'localizedName': 'white pepper',
#        'image': 'white-pepper.png'},
#       {'id': 1230,
#        'name': 'buttermilk',
#        'localizedName': 'buttermilk',
#        'image': 'buttermilk.jpg'},
#       {'id': 11352,
#        'name': 'potato',
#        'localizedName': 'potato',
#        'image': 'potatoes-yukon-gold.png'},
#       {'id': 2025,
#        'name': 'nutmeg',
#        'localizedName': 'nutmeg',
#        'image': 'ground-nutmeg.jpg'},
#       {'id': 2047,
#        'name': 'salt',
#        'localizedName': 'salt',
#        'image': 'salt.jpg'}],
#      'equipment': [{'id': 221439,
#        'name': 'kitchen towels',
#        'localizedName': 'kitchen towels',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/dish-towel.jpg'},
#       {'id': 404752,
#        'name': 'pot',
#        'localizedName': 'pot',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/stock-pot.jpg'}],
#      'length': {'number': 15, 'unit': 'minutes'}},
#     {'number': 8,
#      'step': 'For the brown onion sauce, while the bangers and mash are cooking, heat the oil in a high-sided skillet on medium high heat, add the onions, dill, caraway and mustard seed and cook, uncovered, 5 minutes without stirring.',
#      'ingredients': [{'id': 2024,
#        'name': 'mustard seeds',
#        'localizedName': 'mustard seeds',
#        'image': 'mustard-seeds.png'},
#       {'id': 10511282,
#        'name': 'yellow onion',
#        'localizedName': 'yellow onion',
#        'image': 'brown-onion.png'},
#       {'id': 2005,
#        'name': 'caraway seeds',
#        'localizedName': 'caraway seeds',
#        'image': 'caraway-seeds.jpg'},
#       {'id': 11282,
#        'name': 'onion',
#        'localizedName': 'onion',
#        'image': 'brown-onion.png'},
#       {'id': 0, 'name': 'sauce', 'localizedName': 'sauce', 'image': ''},
#       {'id': 2045,
#        'name': 'dill',
#        'localizedName': 'dill',
#        'image': 'dill.jpg'},
#       {'id': 4582,
#        'name': 'cooking oil',
#        'localizedName': 'cooking oil',
#        'image': 'vegetable-oil.jpg'}],
#      'equipment': [{'id': 404645,
#        'name': 'frying pan',
#        'localizedName': 'frying pan',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/pan.png'}],
#      'length': {'number': 5, 'unit': 'minutes'}},
#     {'number': 9,
#      'step': 'Add the sliced apple, stir once, cover and cook for 5 minutes.',
#      'ingredients': [{'id': 9003,
#        'name': 'apple',
#        'localizedName': 'apple',
#        'image': 'https://spoonacular.com/cdn/ingredients_100x100/apple.jpg'}],
#      'equipment': [],
#      'length': {'number': 5, 'unit': 'minutes'}},
#     {'number': 10,
#      'step': 'Pour in the stock and wine, stirring and scraping all the pan residues up into the liquid until the bottom of the pan is perfectly clean, and simmer 5 minutes.',
#      'ingredients': [{'id': 1006615,
#        'name': 'stock',
#        'localizedName': 'stock',
#        'image': 'chicken-broth.png'},
#       {'id': 14084,
#        'name': 'wine',
#        'localizedName': 'wine',
#        'image': 'red-wine.jpg'}],
#      'equipment': [{'id': 404645,
#        'name': 'frying pan',
#        'localizedName': 'frying pan',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/pan.png'}],
#      'length': {'number': 5, 'unit': 'minutes'}},
#     {'number': 11,
#      'step': 'Remove from the heat, stir in the arrowroot slurry, return to the heat, and bring to a boil to thicken, about 30 seconds. Mash the reserved baked apple, stir into the sauce, and set aside.',
#      'ingredients': [{'id': 20003,
#        'name': 'arrowroot',
#        'localizedName': 'arrowroot',
#        'image': 'white-powder.jpg'},
#       {'id': 9003,
#        'name': 'apple',
#        'localizedName': 'apple',
#        'image': 'https://spoonacular.com/cdn/ingredients_100x100/apple.jpg'},
#       {'id': 0, 'name': 'sauce', 'localizedName': 'sauce', 'image': ''}],
#      'equipment': []},
#     {'number': 12,
#      'step': 'To serve place one scoop each of the mashed potatoes, apple and rutabaga down the centre of each serving plate. Slice each sausage into quarters lengthways. Ladle some sauce on one side of the mash and top the sauce with three quarters of sausage. Spoon some peas on the other side of the mash.',
#      'ingredients': [{'id': 11352,
#        'name': 'potato',
#        'localizedName': 'potato',
#        'image': 'potatoes-yukon-gold.png'},
#       {'id': 11435,
#        'name': 'rutabaga',
#        'localizedName': 'rutabaga',
#        'image': 'rutabaga.jpg'},
#       {'id': 1017063,
#        'name': 'sausage',
#        'localizedName': 'sausage',
#        'image': 'raw-pork-sausage.png'},
#       {'id': 9003,
#        'name': 'apple',
#        'localizedName': 'apple',
#        'image': 'https://spoonacular.com/cdn/ingredients_100x100/apple.jpg'},
#       {'id': 0, 'name': 'sauce', 'localizedName': 'sauce', 'image': ''},
#       {'id': 11304,
#        'name': 'peas',
#        'localizedName': 'peas',
#        'image': 'peas.jpg'}],
#      'equipment': [{'id': 404630,
#        'name': 'ladle',
#        'localizedName': 'ladle',
#        'image': 'https://spoonacular.com/cdn/equipment_100x100/ladle.jpg'}]},
#     {'number': 13,
#      'step': 'Garnish with parsley and a tablespoon of the mustard mixture next to the sausage.',
#      'ingredients': [{'id': 2046,
#        'name': 'mustard',
#        'localizedName': 'mustard',
#        'image': 'regular-mustard.jpg'},
#       {'id': 11297,
#        'name': 'parsley',
#        'localizedName': 'parsley',
#        'image': 'parsley.jpg'},
#       {'id': 1017063,
#        'name': 'sausage',
#        'localizedName': 'sausage',
#        'image': 'raw-pork-sausage.png'}],
#      'equipment': []}]}],
#  'originalId': None,
#  'spoonacularScore': 20.40085792541504,
#  'spoonacularSourceUrl': 'https://spoonacular.com/bangers-and-mash-44789'}

# %%
key = "5cb09004fe27449689868405b5a33789"
recipe_info = requests.get(f"https://api.spoonacular.com/recipes/673463/information?apiKey={key}").json()
recipe_info["diets"]
# Out:
# ['gluten free', 'dairy free']

# %%
key = "5cb09004fe27449689868405b5a33789"
recipe_info = requests.get(f"https://api.spoonacular.com/recipes/673463/information?apiKey={key}").json()
if recipe_info["cuisines"]:
    print(recipe_info["cuisines"])
else:
    print("No cuisine defined!")
# Out:
# No cuisine defined!
